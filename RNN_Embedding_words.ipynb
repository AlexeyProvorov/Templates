Пусть позитив будет вашим вторым именем. Ваша позитивность станет щитом вокруг вас, который защитит вас от стрелы негатива.
Если вы настроены позитивно, то увидите возможности, а не препятствия.
Позитивное мышление и визуализация моего успеха были моими ключами к успеху.
Только хорошее действие в сочетании с позитивным мышлением приводит к успеху.
Чтобы создать радугу, нужны солнечный свет и дождь, а без них не было бы радуги.
Худшие времена могут стать лучшими, если вы думаете о них с хорошим настроем.'''


texts = texts.replace('\ufeff', '')  # убираем первый невидимый символ

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

import numpy as np

from tensorflow.keras.layers import Dense, SimpleRNN, Input, Embedding
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.text import Tokenizer, text_to_word_sequence
from tensorflow.keras.utils import to_categorical

# with open('text', 'r', encoding='utf-8') as f:
#     texts = f.read()
#     texts = texts.replace('\ufeff', '')  # убираем первый невидимый символ

maxWordsCount = 1000
tokenizer = Tokenizer(num_words=maxWordsCount, filters='!–"—#$%&amp;()*+,-./:;<=>?@[\\]^_`{|}~\t\n\r«»',
                      lower=True, split=' ', char_level=False)
tokenizer.fit_on_texts([texts])

dist = list(tokenizer.word_counts.items())
print(dist[:10])

data = tokenizer.texts_to_sequences([texts])
# res = to_categorical(data[0], num_classes=maxWordsCount)
# print(res.shape)
res = np.array( data[0] )

inp_words = 3
n = res.shape[0] - inp_words

X = np.array([res[i:i + inp_words] for i in range(n)])
Y = to_categorical(res[inp_words:], num_classes=maxWordsCount)

model = Sequential()
model.add(Embedding(maxWordsCount, 256, input_length = inp_words))
model.add(SimpleRNN(128, activation='tanh'))
model.add(Dense(maxWordsCount, activation='softmax'))
model.summary()

model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer='adam')

history = model.fit(X, Y, batch_size=32, epochs=50)


def buildPhrase(texts, str_len=20):
    res = texts
    data = tokenizer.texts_to_sequences([texts])[0]
    for i in range(str_len):
        # x = to_categorical(data[i: i + inp_words], num_classes=maxWordsCount)  # преобразуем в One-Hot-encoding
        # inp = x.reshape(1, inp_words, maxWordsCount)
        x = data[i: i + inp_words]
        inp = np.expand_dims(x, axis=0)

        pred = model.predict(inp)
        indx = pred.argmax(axis=1)[0]
        data.append(indx)

        res += " " + tokenizer.index_word[indx]  # дописываем строку

    return res


res = buildPhrase("позитив добавляет годы")
print(res)
# Out:
# [('я', 21), ('притягиваю', 1), ('только', 21), ('плохое', 1), ('кому', 2), ('нужен', 2), ('с', 12), ('такой', 5), ('внешностью', 2), ('не', 91)]
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 3, 256)            256000
#
#  simple_rnn (SimpleRNN)      (None, 128)               49280
#
#  dense (Dense)               (None, 1000)              129000
#
# =================================================================
# Total params: 434280 (1.66 MB)
# Trainable params: 434280 (1.66 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/50
# 52/52 [==============================] - 2s 16ms/step - loss: 6.8551 - accuracy: 0.0409
# Epoch 2/50
# 52/52 [==============================] - 1s 17ms/step - loss: 6.1644 - accuracy: 0.0553
# Epoch 3/50
# 52/52 [==============================] - 1s 17ms/step - loss: 5.7314 - accuracy: 0.0781
# Epoch 4/50
# 52/52 [==============================] - 1s 13ms/step - loss: 5.2374 - accuracy: 0.1352
# Epoch 5/50
# 52/52 [==============================] - 1s 10ms/step - loss: 4.6180 - accuracy: 0.2031
# Epoch 6/50
# 52/52 [==============================] - 1s 11ms/step - loss: 3.9659 - accuracy: 0.3179
# Epoch 7/50
# 52/52 [==============================] - 1s 10ms/step - loss: 3.3252 - accuracy: 0.4742
# Epoch 8/50
# 52/52 [==============================] - 1s 10ms/step - loss: 2.7420 - accuracy: 0.5950
# Epoch 9/50
# 52/52 [==============================] - 1s 10ms/step - loss: 2.2286 - accuracy: 0.6755
# Epoch 10/50
# 52/52 [==============================] - 1s 10ms/step - loss: 1.7984 - accuracy: 0.7554
# Epoch 11/50
# 52/52 [==============================] - 1s 10ms/step - loss: 1.4384 - accuracy: 0.8233
# Epoch 12/50
# 52/52 [==============================] - 1s 10ms/step - loss: 1.1544 - accuracy: 0.8690
# Epoch 13/50
# 52/52 [==============================] - 1s 10ms/step - loss: 0.9294 - accuracy: 0.9081
# Epoch 14/50
# 52/52 [==============================] - 1s 10ms/step - loss: 0.7540 - accuracy: 0.9345
# Epoch 15/50
# 52/52 [==============================] - 1s 10ms/step - loss: 0.6119 - accuracy: 0.9555
# Epoch 16/50
# 52/52 [==============================] - 1s 10ms/step - loss: 0.4982 - accuracy: 0.9651
# Epoch 17/50
# 52/52 [==============================] - 1s 10ms/step - loss: 0.4120 - accuracy: 0.9748
# Epoch 18/50
# 52/52 [==============================] - 1s 10ms/step - loss: 0.3435 - accuracy: 0.9826
# Epoch 19/50
# 52/52 [==============================] - 1s 10ms/step - loss: 0.2845 - accuracy: 0.9868
# Epoch 20/50
# 52/52 [==============================] - 1s 10ms/step - loss: 0.2417 - accuracy: 0.9880
# Epoch 21/50
# 52/52 [==============================] - 1s 10ms/step - loss: 0.2073 - accuracy: 0.9856
# Epoch 22/50
# 52/52 [==============================] - 1s 10ms/step - loss: 0.1797 - accuracy: 0.9862
# Epoch 23/50
# 52/52 [==============================] - 1s 15ms/step - loss: 0.1579 - accuracy: 0.9886
# Epoch 24/50
# 52/52 [==============================] - 1s 17ms/step - loss: 0.1387 - accuracy: 0.9874
# Epoch 25/50
# 52/52 [==============================] - 1s 17ms/step - loss: 0.1246 - accuracy: 0.9880
# Epoch 26/50
# 52/52 [==============================] - 1s 13ms/step - loss: 0.1116 - accuracy: 0.9886
# Epoch 27/50
# 52/52 [==============================] - 1s 10ms/step - loss: 0.1011 - accuracy: 0.9868
# Epoch 28/50
# 52/52 [==============================] - 1s 10ms/step - loss: 0.0923 - accuracy: 0.9904
# Epoch 29/50
# 52/52 [==============================] - 1s 10ms/step - loss: 0.0851 - accuracy: 0.9892
# Epoch 30/50
# 52/52 [==============================] - 1s 10ms/step - loss: 0.0789 - accuracy: 0.9886
# Epoch 31/50
# 52/52 [==============================] - 1s 10ms/step - loss: 0.0740 - accuracy: 0.9880
# Epoch 32/50
# 52/52 [==============================] - 1s 10ms/step - loss: 0.0685 - accuracy: 0.9880
# Epoch 33/50
# 52/52 [==============================] - 1s 10ms/step - loss: 0.0652 - accuracy: 0.9898
# Epoch 34/50
# 52/52 [==============================] - 1s 10ms/step - loss: 0.0606 - accuracy: 0.9868
# Epoch 35/50
# 52/52 [==============================] - 1s 10ms/step - loss: 0.0576 - accuracy: 0.9886
# Epoch 36/50
# 52/52 [==============================] - 1s 10ms/step - loss: 0.0538 - accuracy: 0.9892
# Epoch 37/50
# 52/52 [==============================] - 1s 10ms/step - loss: 0.0515 - accuracy: 0.9880
# Epoch 38/50
# 52/52 [==============================] - 1s 10ms/step - loss: 0.0492 - accuracy: 0.9886
# Epoch 39/50
# 52/52 [==============================] - 1s 10ms/step - loss: 0.0475 - accuracy: 0.9886
# Epoch 40/50
# 52/52 [==============================] - 1s 10ms/step - loss: 0.0457 - accuracy: 0.9898
# Epoch 41/50
# 52/52 [==============================] - 1s 10ms/step - loss: 0.0450 - accuracy: 0.9874
# Epoch 42/50
# 52/52 [==============================] - 1s 11ms/step - loss: 0.0425 - accuracy: 0.9898
# Epoch 43/50
# 52/52 [==============================] - 1s 10ms/step - loss: 0.0408 - accuracy: 0.9886
# Epoch 44/50
# 52/52 [==============================] - 1s 10ms/step - loss: 0.0390 - accuracy: 0.9868
# Epoch 45/50
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0368 - accuracy: 0.9898
# Epoch 46/50
# 52/52 [==============================] - 1s 17ms/step - loss: 0.0369 - accuracy: 0.9880
# Epoch 47/50
# 52/52 [==============================] - 1s 17ms/step - loss: 0.0358 - accuracy: 0.9898
# Epoch 48/50
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0352 - accuracy: 0.9874
# Epoch 49/50
# 52/52 [==============================] - 1s 10ms/step - loss: 0.0336 - accuracy: 0.9880
# Epoch 50/50
# 52/52 [==============================] - 1s 10ms/step - loss: 0.0335 - accuracy: 0.9892
# 1/1 [==============================] - 0s 179ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# позитив добавляет годы счастье вашей жизни и двигаться приверженным стремлению вы это у вас не потенциала чем почему кажется но вы ли многого
